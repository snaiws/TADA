# %%
import os  
import sys  
import zipfile  
import tempfile  
import shutil  
from tqdm.notebook import tqdm  
from dotenv import load_dotenv  

# 프로젝트 루트 경로 설정  
#sys.path.append('./src')  


from update_objectfile import upload_file_with_metadata  
from data_engineering.obj_storage.boto3 import MinIOClient  
from data_engineering.db.connector import Database

# %%
# 환경 변수 로드  
load_dotenv('.env')  

# MinIO 클라이언트 초기화  
minio_client = MinIOClient()  

# 데이터셋 경로 설정 (상대 경로 사용)  
DATASET_PATH = "../../DataSet"  

# 처리할 디렉토리 구조  
DIRECTORIES = [  
    "Training/01.원천데이터",  
    "Training/02.라벨링데이터",  
    "Validation/01.원천데이터",  
    "Validation/02.라벨링데이터"  
]

# %%
# 버킷 이름 설정  
BUCKET_NAME = "tada"  

# 지원하는 이미지 확장자  
IMAGE_EXTENSIONS = {".jpg", ".jpeg", ".png", ".gif", ".bmp"}  

def is_image_file(filename):  
    return any(filename.lower().endswith(ext) for ext in IMAGE_EXTENSIONS)  

def get_uploaded_files():  
    """DB에서 이미 업로드된 파일 목록 가져오기"""  
    db = Database(  
        host=os.getenv('DB_HOST'),  
        port=int(os.getenv('DB_PORT')),  
        user=os.getenv('DB_USER'),  
        password=os.getenv('DB_PASSWORD'),  
        database=os.getenv('DB_NAME')  
    )  
    
    query = "SELECT category, object_path FROM object_storage"  
    results = db.getter(query)  
    return {(record['category'], record['object_path']) for record in results}

# %%
# DB 테이블 생성 확인  
from data_engineering.db.init_db import create_object_storage_table  
create_object_storage_table()  

# 이미 업로드된 파일 목록 가져오기  
uploaded_files = get_uploaded_files()  
print(f"이미 업로드된 파일 수: {len(uploaded_files)}")  

# 임시 디렉토리 생성  
temp_dir = tempfile.mkdtemp()  
print(f"임시 디렉토리 생성됨: {temp_dir}")  

try:  
    # 각 디렉토리 처리  
    for dir_path in DIRECTORIES:  
        current_path = os.path.join(DATASET_PATH, dir_path)  
        print(f"\n처리 중인 디렉토리: {dir_path}")  
        
        # ZIP 파일 목록 가져오기  
        zip_files = [f for f in os.listdir(current_path) if f.endswith('.zip')]  
        print(f"발견된 ZIP 파일 수: {len(zip_files)}")  
        
        # 각 ZIP 파일 처리  
        for zip_filename in tqdm(zip_files, desc="ZIP 파일 처리 중"):  
            zip_path = os.path.join(current_path, zip_filename)  
            category = f"{dir_path}/{os.path.splitext(zip_filename)[0]}"  
            
            with zipfile.ZipFile(zip_path, 'r') as zip_ref:  
                for file_info in tqdm(zip_ref.filelist, desc="파일 추출 중"):  
                    if is_image_file(file_info.filename):  
                        object_key = f"{category}/{os.path.basename(file_info.filename)}"  
                        
                        # 이미 업로드된 파일 건너뛰기  
                        if (category, object_key) in uploaded_files:  
                            continue  
                        
                        # 임시 파일로 추출  
                        temp_path = os.path.join(temp_dir, os.path.basename(file_info.filename))  
                        with zip_ref.open(file_info) as source, open(temp_path, 'wb') as target:  
                            shutil.copyfileobj(source, target)  
                        
                        try:  
                            # MinIO 업로드 및 메타데이터 저장  
                            success = upload_file_with_metadata(  
                                local_path=temp_path,  
                                category=category,  
                                bucket=BUCKET_NAME,  
                                object_path=object_key  
                            )  
                            if not success:  
                                print(f"업로드 실패: {object_key}")  
                        except Exception as e:  
                            print(f"처리 실패: {object_key} - {str(e)}")  
                        
                        # 임시 파일 삭제  
                        os.remove(temp_path)  

finally:  
    # 임시 디렉토리 정리  
    shutil.rmtree(temp_dir)  
    print("임시 디렉토리 정리 완료")
# Out:
# object_storage 테이블이 성공적으로 생성되었습니다.
# 이미 업로드된 파일 수: 13838
# 임시 디렉토리 생성됨: C:\Users\dongr\AppData\Local\Temp\tmpc16pon_w
#
# 처리 중인 디렉토리: Training/01.원천데이터
# 발견된 ZIP 파일 수: 8
# ZIP 파일 처리 중:   0%|          | 0/8 [00:00<?, ?it/s]
# 파일 추출 중:   0%|          | 0/6058 [00:00<?, ?it/s]
# Upload error: Read timeout on endpoint URL: "http://175.214.62.133:50008/tada/Training/01.%EC%9B%90%EC%B2%9C%EB%8D%B0%EC%9D%B4%ED%84%B0/TS_OBJ_1/APT_FP_OBJ_037344144.PNG?uploadId=ZDY0N2RlZjMtYWRlMi00MWY1LThkMWUtZmQ5YjA5NTE5ZTE4LmZkMDIxODhlLWM3NmEtNDE2YS04MWViLWZjYjBlMTE0NjFjY3gxNzMyNTQ2OTg1OTg2ODc5MTA3"
# 업로드 실패: Training/01.원천데이터/TS_OBJ_1/APT_FP_OBJ_037344144.PNG
# 파일 추출 중:   0%|          | 0/2041 [00:00<?, ?it/s]
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada/Training/01.%EC%9B%90%EC%B2%9C%EB%8D%B0%EC%9D%B4%ED%84%B0/TS_OBJ_2/APT_FP_OBJ_985691754.PNG?uploadId=ZDY0N2RlZjMtYWRlMi00MWY1LThkMWUtZmQ5YjA5NTE5ZTE4LjUzOTAwOTJjLTMyOTEtNGEwMC1hMDE3LTNiMWZkYzQ0OTBlNngxNzMyNTYyNjk0MjUzMDYwNzgy&partNumber=1".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_985691754.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_983508955.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_983560055.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_983848789.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_988329155.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_986442407.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_992759706.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_984379454.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_986156985.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_997356667.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_986502948.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_985084113.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_985557682.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_985322309.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_987002911.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_985105368.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_987292263.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_985534584.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_990954189.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_993133727.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_036935206.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_986379347.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_986376808.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_989190063.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_986742302.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_986452402.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_987024025.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_991528548.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_989920172.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_987483235.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_994505402.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_992501533.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_987517283.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_987746936.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_988300881.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_990864369.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_988283169.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_988325458.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_994018042.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_018200019.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_992352257.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_989332943.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_989671446.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_994983478.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_989805888.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_992668919.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_997579028.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_990356407.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_990895227.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_993533889.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_013149685.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_993184656.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_990452319.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_992038465.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_991420334.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_993442651.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_991066732.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_992208361.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_992447072.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_997007878.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_994269949.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_992530714.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_992677418.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_995354414.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_995276975.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_997171531.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_995360858.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_993285541.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_999143702.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_995572349.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_996530215.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_994043266.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_994258187.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_994890487.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_012517189.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_996615188.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_994943513.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_025582597.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_995080023.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_995325841.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_997104851.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_059735413.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_995532355.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_083066974.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_995615273.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_996484939.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_995556668.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_996533864.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_005398721.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_999098385.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_996707803.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_022090464.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_996916023.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_996732021.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_997085801.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_999791325.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_997181195.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_997158219.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_997304676.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_999427255.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_997274753.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_999864474.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_019840383.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_997199528.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_998458678.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_008695512.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_998577397.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_998054415.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_999211166.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_999403215.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_009177183.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_035987417.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_999244946.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_999233003.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_002113503.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/APT_FP_OBJ_999593321.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_124652462.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_021847035.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_002529769.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_023477578.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_076371674.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_005626753.png
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_169058781.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_007522916.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_030977947.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_013140654.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_119508149.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_016429172.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_016627671.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_016967479.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_039752094.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_039708797.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_072181072.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_020641977.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_094404017.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_050948229.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_021944873.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_059430222.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_022617714.png
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_050412807.png
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_083166202.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_033246202.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_033789662.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_063782436.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_224033423.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_039732371.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_042386818.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_045172828.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_044785298.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_072965264.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_053964112.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_092045499.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_071144364.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_058566301.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_077019735.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_059342951.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_103480959.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_061656479.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_062330831.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_172716612.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_084884359.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_062893528.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_064523805.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_065137701.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_068700647.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_090634529.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_122916509.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_097772326.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_102948201.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_076807431.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_134021512.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_082007722.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_189117924.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_083696198.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_126604191.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_086135494.PNG
# Upload error: Connection was closed before we received a valid response from endpoint URL: "http://175.214.62.133:50008/tada".
# 업로드 실패: Training/01.원천데이터/TS_OBJ_2/DEH_FP_OBJ_106630541.PNG
# 임시 디렉토리 정리 완료
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File c:\ProgramData\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File c:\ProgramData\anaconda3\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File c:\ProgramData\anaconda3\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     719 try:
# --> 720     return self._sock.recv_into(b)
#     721 except timeout:
#
# ConnectionResetError: [WinError 10054] 현재 연결은 원격 호스트에 의해 강제로 끊겼습니다
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 44
#      40     shutil.copyfileobj(source, target)
#      42 try:
#      43     # MinIO 업로드 및 메타데이터 저장
# ---> 44     success = upload_file_with_metadata(
#      45         local_path=temp_path,
#      46         category=category,
#      47         bucket=BUCKET_NAME,
#      48         object_path=object_key
#      49     )
#      50     if not success:
#      51         print(f"업로드 실패: {object_key}")
#
# File g:\Dropbox\OssmMath\52_AI-Project\TADA\src\update_objectfile.py:21, in upload_file_with_metadata(local_path, category, bucket, object_path)
#      18     object_path = os.path.basename(local_path)
#      20 # 파일 업로드
# ---> 21 if not minio_client.upload_file(local_path, bucket, object_path):
#      22     return False
#      24 # DB 연결 (싱글톤)
#      25 #load_dotenv()
#
# File g:\Dropbox\OssmMath\52_AI-Project\TADA\src\data_engineering\obj_storage\boto3.py:64, in MinIOClient.upload_file(self, local_path, bucket, object_path)
#      62 """파일 업로드"""
#      63 try:
# ---> 64     if not self.ensure_bucket_exists(bucket):
#      65         raise Exception(f"버킷 '{bucket}' 생성/확인 실패")
#      67     self.client.upload_file(local_path, bucket, object_path)
#
# File g:\Dropbox\OssmMath\52_AI-Project\TADA\src\data_engineering\obj_storage\boto3.py:57, in MinIOClient.ensure_bucket_exists(self, bucket_name)
#      55 def ensure_bucket_exists(self, bucket_name: str) -> bool:
#      56     """버킷이 없으면 생성"""
# ---> 57     if not self.check_bucket_exists(bucket_name):
#      58         return self.create_bucket(bucket_name)
#      59     return True
#
# File g:\Dropbox\OssmMath\52_AI-Project\TADA\src\data_engineering\obj_storage\boto3.py:41, in MinIOClient.check_bucket_exists(self, bucket_name)
#      39 """버킷 존재 여부 확인"""
#      40 try:
# ---> 41     self.client.head_bucket(Bucket=bucket_name)
#      42     return True
#      43 except ClientError:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\botocore\client.py:569, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     565     raise TypeError(
#     566         f"{py_operation_name}() only accepts keyword arguments."
#     567     )
#     568 # The "self" in this scope is referring to the BaseClient.
# --> 569 return self._make_api_call(operation_name, kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\botocore\client.py:1005, in BaseClient._make_api_call(self, operation_name, api_params)
#    1001     maybe_compress_request(
#    1002         self.meta.config, request_dict, operation_model
#    1003     )
#    1004     apply_request_checksum(request_dict)
# -> 1005     http, parsed_response = self._make_request(
#    1006         operation_model, request_dict, request_context
#    1007     )
#    1009 self.meta.events.emit(
#    1010     f'after-call.{service_id}.{operation_name}',
#    1011     http_response=http,
#    (...)
#    1014     context=request_context,
#    1015 )
#    1017 if http.status_code >= 300:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\botocore\client.py:1029, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#    1027 def _make_request(self, operation_model, request_dict, request_context):
#    1028     try:
# -> 1029         return self._endpoint.make_request(operation_model, request_dict)
#    1030     except Exception as e:
#    1031         self.meta.events.emit(
#    1032             f'after-call-error.{self._service_model.service_id.hyphenize()}.{operation_model.name}',
#    1033             exception=e,
#    1034             context=request_context,
#    1035         )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\botocore\endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#     113 def make_request(self, operation_model, request_dict):
#     114     logger.debug(
#     115         "Making request for %s with params: %s",
#     116         operation_model,
#     117         request_dict,
#     118     )
# --> 119     return self._send_request(request_dict, operation_model)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\botocore\endpoint.py:216, in Endpoint._send_request(self, request_dict, operation_model)
#     214     # Create a new request when retried (including a new signature).
#     215     request = self.create_request(request_dict, operation_model)
# --> 216     success_response, exception = self._get_response(
#     217         request, operation_model, context
#     218     )
#     219 if (
#     220     success_response is not None
#     221     and 'ResponseMetadata' in success_response[1]
#     222 ):
#     223     # We want to share num retries, not num attempts.
#     224     total_retries = attempts - 1
#
# File ~\AppData\Roaming\Python\Python312\site-packages\botocore\endpoint.py:239, in Endpoint._get_response(self, request, operation_model, context)
#     233 def _get_response(self, request, operation_model, context):
#     234     # This will return a tuple of (success_response, exception)
#     235     # and success_response is itself a tuple of
#     236     # (http_response, parsed_dict).
#     237     # If an exception occurs then the success_response is None.
#     238     # If no exception occurs then exception is None.
# --> 239     success_response, exception = self._do_get_response(
#     240         request, operation_model, context
#     241     )
#     242     kwargs_to_emit = {
#     243         'response_dict': None,
#     244         'parsed_response': None,
#     245         'context': context,
#     246         'exception': exception,
#     247     }
#     248     if success_response is not None:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\botocore\endpoint.py:279, in Endpoint._do_get_response(self, request, operation_model, context)
#     277     http_response = first_non_none_response(responses)
#     278     if http_response is None:
# --> 279         http_response = self._send(request)
#     280 except HTTPClientError as e:
#     281     return (None, e)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\botocore\endpoint.py:383, in Endpoint._send(self, request)
#     382 def _send(self, request):
# --> 383     return self.http_session.send(request)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\botocore\httpsession.py:464, in URLLib3Session.send(self, request)
#     461     conn.proxy_headers['host'] = host
#     463 request_target = self._get_request_target(request.url, proxy_url)
# --> 464 urllib_response = conn.urlopen(
#     465     method=request.method,
#     466     url=request_target,
#     467     body=request.body,
#     468     headers=request.headers,
#     469     retries=Retry(False),
#     470     assert_same_host=False,
#     471     preload_content=False,
#     472     decode_content=False,
#     473     chunked=self._chunked(request.headers),
#     474 )
#     476 http_response = botocore.awsrequest.AWSResponse(
#     477     request.url,
#     478     urllib_response.status,
#     479     urllib_response.headers,
#     480     urllib_response,
#     481 )
#     483 if not request.stream_output:
#     484     # Cause the raw stream to be exhausted immediately. We do it
#     485     # this way instead of using preload_content because
#     486     # preload_content will never buffer chunked responses
#
# File c:\ProgramData\anaconda3\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\ProgramData\anaconda3\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File c:\ProgramData\anaconda3\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428     response.begin()
#    1429 except ConnectionError:
# -> 1430     self.close()
#    1431     raise
#    1432 assert response.will_close != _UNKNOWN
#
# File ~\AppData\Roaming\Python\Python312\site-packages\botocore\awsrequest.py:79, in AWSConnection.close(self)
#      76     self._expect_header_set = False
#      77     self._send_called = False
# ---> 79 def close(self):
#      80     super().close()
#      81     # Reset all of our instance state we were tracking.
#
# KeyboardInterrupt:

# %%
# 최종 상태 확인  
db = Database(  
    host=os.getenv('DB_HOST'),  
    port=int(os.getenv('DB_PORT')),  
    user=os.getenv('DB_USER'),  
    password=os.getenv('DB_PASSWORD'),  
    database=os.getenv('DB_NAME')  
)  

query = "SELECT COUNT(*) as count FROM object_storage"  
result = db.getter(query)  
print(f"\n총 업로드된 파일 수: {result[0]['count']}")  

# 카테고리별 통계 확인  
query = """  
SELECT category, COUNT(*) as count   
FROM object_storage   
GROUP BY category   
ORDER BY count DESC  
"""  
records = db.getter(query)  
print("\n카테고리별 파일 수:")  
for record in records:  
    print(f"- {record['category']}: {record['count']}개")
